# %% [markdown]
# ### IMPORTS AND CONN ESTABLISHMENT

# %%
import os
import csv
import pandas as pd
from openai import OpenAI
from neo4j import GraphDatabase
# import genai
from dotenv import load_dotenv
load_dotenv()
import tiktoken
import yaml
# from utils.embeddings_utils import get_embedding

# %%
class Neo4jConnection:
    def __init__(self, uri, user, pwd):
        self.__uri = uri
        self.__user = user
        self.__pwd = pwd
        self.__driver = None
        try:
            self.__driver = GraphDatabase.driver(self.__uri, auth=(self.__user, self.__pwd))
        except Exception as e:
            print("Failed to create the driver:", e)
    def close(self):
        if self.__driver is not None:
            self.__driver.close()
    def query(self, query, parameters=None, db=None):
        assert self.__driver is not None, "Driver not initialized!"
        session = None
        response = None
        try: 
            session = self.__driver.session(database=db) if db is not None else self.__driver.session() 
            response = list(session.run(query, parameters))
        except Exception as e:
            print("Query failed:", e)
        finally: 
            if session is not None:
                session.close()
        return response

# %%
with open("../config.yaml", "r") as file:
    config = yaml.safe_load(file)

# Accessing keys and credentials
openai_api_key = config["openai"]["api_key"]
neo4j_uri = config["neo4j"]["uri"]
neo4j_user = config["neo4j"]["user"]
neo4j_password = config["neo4j"]["password"]
user = config['user']['quest']

# %%
## Connection Strings
conn = Neo4jConnection(uri=neo4j_uri, user=neo4j_user, pwd=neo4j_password)
from py2neo import Graph, Node, Relationship, NodeMatcher
conn.query("MATCH (n) RETURN COUNT(n)")

# Establish connection
graph = Graph(neo4j_uri, auth=(neo4j_user, neo4j_password))

### Checking the connection by looking over the data in the Database
graph.run("MATCH (n) return count(n)")
# Out:
#  count(n)
# ----------
#     46206

# %% [markdown]
# ### CREATING EMBEDDINGS

# %%
embedding_model = "text-embedding-3-small"
embedding_encoding = "cl100k_base"
max_tokens = 8000

# %%
def get_plots(limit=None):
    driver = GraphDatabase.driver('bolt://localhost:7687',auth=("neo4j",pwd))
    driver.verify_connectivity()
    query = """MATCH (m:ARTICLE) WHERE m.detail_desc IS NOT NULL
    RETURN m.article_id AS id,m.title as title, m.product_group_name AS product_group_name, m.product_type_name as product_type_name, m.detail_desc as detail_desc """
    movies, summary, keys = driver.execute_query(
        query
    )
    driver.close()
    return movies

# %%
def generate_embeddings(file_name, limit=None):
    csvfile_out = open(file_name, 'w', encoding='utf8', newline='')
    fieldnames = ['title','embedding']
    output_plot = csv.DictWriter(csvfile_out, fieldnames=fieldnames)
    output_plot.writeheader()
    movies = get_plots(limit=limit)
#     print(len(movies))
    llm = OpenAI(api_key=openai_api_key)
    for movie in movies:
#         print(movie['title'])
        desc = f"{movie['detail_desc']}"
        response = llm.embeddings.create(
            input=desc,
            model='text-embedding-ada-002')
        output_plot.writerow({
            'title': movie['title'],
            'embedding': response.data[0].embedding
        })

    csvfile_out.close()
generate_embeddings('detail-plot-embeddings.csv')

# %%
df = pd.read_csv("detail-plot-embeddings.csv")

# %% [markdown]
# #### Adding embeddings back to DataBase

# %%
for index, row in df.iterrows():
    if row['embedding'] is not None:
        graph.run("""
        MATCH (a:ARTICLE {title: $title})
        SET a.embedding = apoc.convert.fromJsonList($embedding)
        """, title=row['title'], embedding=row['embedding'])

# %%
# query = """MATCH (n:ARTICLE)
# RETURN n.article_id AS ArticleID, apoc.meta.type(n.article_id) AS Type
# LIMIT 10;"""

# conn.query(query)

# %%
# result = graph.run("MATCH (a:ARTICLE) RETURN a.article_id AS article_id, a.embedding AS embedding").data()

# # Prepare embeddings for similarity search
# article_ids = [row['article_id'] for row in result]
# embeddings = [row['embedding'] for row in result]

# %%
# from sklearn.metrics.pairwise import cosine_similarity
# import numpy as np

# # Compute similarity scores
# similarities = cosine_similarity([Ques_embedding], embeddings)

# # Rank articles by similarity
# sorted_indices = np.argsort(-similarities[0])  # Descending order
# top_articles = [(article_ids[i], similarities[0][i]) for i in sorted_indices[:5]]  # Top 5
# print("Top Recommendations:", top_articles)

# %% [markdown]
# ### CREATING VECTOR INDEX
# ##### to perform vector search

# %%
query_vectorIndex = """CREATE VECTOR INDEX moviePlots1 IF NOT EXISTS
FOR (m:ARTICLE)
ON m.embedding
OPTIONS {indexConfig: {
 `vector.dimensions`: 1536,
 `vector.similarity_function`: 'cosine'
}}"""
conn.query(query_vectorIndex)
# Out:
# []

# %% [markdown]
# #### check all the existing vector indexs

# %%
query_checkout_vectors = """SHOW INDEXES  YIELD id, name, type, state, populationPercent WHERE type = "VECTOR" """
graph.run(query_checkout_vectors)
# Out:
#  id | name        | type   | state  | populationPercent
# ----|-------------|--------|--------|-------------------
#   2 | moviePlots1 | VECTOR | ONLINE |             100.0
#   3 | plot        | VECTOR | ONLINE |             100.0

# %% [markdown]
# ### User Query

# %%
user_query = "I have a green hooodie what can it go good with"

# %%
from openai import OpenAI
# Initialize the OpenAI client
client = OpenAI(api_key = openai_api_key)
def get_embedding(text, model="text-embedding-ada-002"):
    # Replace newline characters with spaces
    text = text.replace("\n", " ")
    # Call OpenAI API to get embeddings
    embedding = client.embeddings.create(input=[text], model=model).data[0].embedding
    return embedding
text_input = user_query
# Get embeddings for the text input
Ques_embedding = get_embedding(text_input, model='text-embedding-ada-002')

# Now 'embedding' variable contains the embeddings for the text input
# print(embedding)

# %%
### Retrieval Using Neo4j

# %%
openaikey = 'openai_api_key'
OPENAI_ENDPOINT = 'https://api.openai.com/v1/'
query_string = """
    CALL db.index.vector.queryNodes(
        'plot', 
        35, 
        $Ques_embedding
        ) YIELD node AS movie, score
    RETURN  movie.article_id, movie.title, movie.detail_desc, score
"""

result = conn.query(query_string, {'Ques_embedding':Ques_embedding
                
})
# print(result)
column_names = ['article_id','title', 'detail_desc', 'similarity_score'] 
answer  = pd.DataFrame(result, columns=column_names)

answer.head(20)
# Out:
#    article_id                      title  \
# 0   626445001         RUSSEL CROP HOODIE
# 1   921918001            ED Dores hoodie
# 2   845734001             LOGG Atwood. 1
# 3   545376001        L.O.G.G. Basic Hood
# 4   711719001           LOGG Velour hood
# 5   735412001         Basic Hood jkt set
# 6   735412005               Hood jkt set
# 7   935547001             ED Nice hoodie
# 8   885803002  Cortina Fleece Jacket (C)
# 9   885803005      Cortina Fleece Jacket
# 10  900258001    LOGG Leea washed hoodie
# 11  939152002                No Lic Iris
# 12  882336002            ED Woody hoodie
# 13  804702001         Beppe layered hood
# 14  887157001        No Lic. Olivia hood
# 15  657044001          Yoshi casual hood
# 16  917610001                 Irene pile
# 17  868045003                Katy fleece
# 18  791144001            IRIS PRICE HOOD
# 19  617809001      DIV Cori cropped hood
#
#                                           detail_desc  similarity_score
# 0   Young Girl Hooded top in printed sweatshirt fa...          0.895126
# 1   H&M+ Long, wide hoodie in soft sweatshirt fabr...          0.894989
# 2   H&M+ Long-sleeved jumper in a soft knit contai...          0.894684
# 3   H&M+ Long-sleeved top in sweatshirt fabric wit...          0.894424
# 4   H&M+ Long-sleeved top in velour with a drawstr...          0.894272
# 5   Baby Essentials & Complements Top, hooded jack...          0.894043
# 6   Baby Essentials & Complements Top, hooded jack...          0.894043
# 7   H&M+ Long hoodie in supersoft cotton jersey wi...          0.893768
# 8   Ladies H&M Sport Hooded jacket in soft fleece ...          0.893738
# 9   Ladies H&M Sport Hooded jacket in soft fleece ...          0.893738
# 10  H&M+ Hoodie in soft sweatshirt fabric made fro...          0.893600
# 11  Young Girl Hoodie in soft sweatshirt fabric wi...          0.893539
# 12  H&M+ Top in soft sweatshirt fabric made from a...          0.893341
# 13  Young Boy Hoodie in soft, fine-knit cotton wit...          0.893280
# 14  Young Girl Cropped hoodie in lightweight, prin...          0.893265
# 15  Young Girl Hooded jacket in sweatshirt fabric ...          0.893219
# 16  Young Girl Hoodie in soft faux shearling with ...          0.893005
# 17  Kids Outerwear Hoodie knitted in soft, thermal...          0.892975
# 18  Young Girl Hooded top in soft sweatshirt fabri...          0.892929
# 19  H&M+ Cropped top in soft sweatshirt fabric wit...          0.892899

# %% [markdown]
# ### Prep to prompt

# %%
### trail 01


import pandas as pd

def prepare_context_from_df(retrieved_items_df):
    context =''
    for idx, row in retrieved_items_df.iterrows():
        context += f"{idx + 1}. {row['title']}: {row['detail_desc']}\n"
    return context

# Example retrieved items as a DataFrame


context = prepare_context_from_df(answer.head(3))
print(context)
# Out:
# 1. RUSSEL CROP HOODIE: Young Girl Hooded top in printed sweatshirt fabric with long sleeves, ribbed cuffs and a raw-edge hem.
# 2. ED Dores hoodie: H&M+ Long, wide hoodie in soft sweatshirt fabric. Double-layered drawstring hood, dropped shoulders, long sleeves, discreet side pockets and ribbing at the cuffs and hem. Soft brushed inside. The polyester content of the hoodie is recycled.
# 3. LOGG Atwood. 1: H&M+ Long-sleeved jumper in a soft knit containing some wool with a drawstring hood, low dropped shoulders, slits in the sides and ribbing at the cuffs and hem. Slightly longer at the back.

# %% [markdown]
# ### Generation Phase

# %%
def generate_answer(user_query, context):
    messages = [
        {"role": "system", "content": "You are a helpful assistant providing product recommendations."},
        {"role": "user", "content": f"User Query: {user_query}\nContext:\n{context}\nProvide a recommendation for what can be paired with the user's described item."}
    ]
    # Generate response
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",  # Use 'gpt-4' for more advanced capabilities
        messages=messages,
        max_tokens=200
    ).to_dict()  # Convert to a dictionary

    # Extract the content
    return response['choices'][0]['message']['content'].strip()

# Example usage
user_query = user
context = context
answer = generate_answer(user_query, context)

# %%
answer
# Out:
# 'Pairing Suggestion: RUSSEL CROP HOODIE - High-waisted distressed jeans and ankle boots.'

# %%
def parse_result_to_dict(result_text):
    result_dict = {}
    for line in result_text.strip().split("\n"):
        key, value = line.split(": ")
        result_dict[key.strip()] = value.strip()
    return result_dict
result_dict = parse_result_to_dict(answer)

# %%
result_dict
# Out:
# {'Pairing Suggestion': 'RUSSEL CROP HOODIE - High-waisted distressed jeans and ankle boots.'}

# %%
answer_embedding = get_embedding(result_dict['Pairing Suggestion'], model='text-embedding-ada-002')

# %%
openaikey = 'openai_api_key'
OPENAI_ENDPOINT = 'https://api.openai.com/v1/'
query_string = """
    CALL db.index.vector.queryNodes(
        'plot', 
        50, 
        $Ques_embedding
        ) YIELD node AS movie, score
    RETURN  movie.article_id, movie.title, movie.detail_desc, score
"""

result = conn.query(query_string, {'Ques_embedding':answer_embedding
                
})
# print(result)
column_names = ['article_id','title', 'detail_desc', 'similarity_score'] 
answer  = pd.DataFrame(result, columns=column_names)

answer
# Out:
#    article_id                           title  \
# 0   571650001              Taylor Fancy Denim
# 1   571650002      Taylor fancy denim Slim LW
# 2   569498002                     Alala Denim
# 3   547871002                    Perrie Fancy
# 4   741752001  Petite Perrie slim mom denim T
# 5   640021001          Perrie Denim Trash TRS
# 6   640021005       Perrie Trash HW Denim TRS
# 7   640021013       Perrie HW Denim Trash TRS
# 8   613279001        Perrie Denim 2 Fancy TRS
# 9   874955001                BELLE FLARE CROP
# 10  620223001                      Beat denim
# 11  780361002               DIV Jade HW Trash
# 12  757926001        Skinny H.W Ankle Festive
# 13  572546001            Jade Denim Fancy TRS
# 14  869912001             Perrie HW Denim TRS
# 15  569041001                   Keys PQ Denim
# 16  607247001           Farah Flare Denim TRS
# 17  484538006                   Perfect denim
# 18  484538002                     Isaac denim
# 19  484538004                   Perfect Denim
# 20  705988005              Molly HW Ankle TRS
# 21  705988001              Molly Denim HW TRS
# 22  777040001            Mother NW wide denim
# 23  668273001              Preston cord flare
# 24  616263001              Appeltini 5 pocket
# 25  708680003               LNY CALCIUM Jeans
# 26  659609001             Jade High Knee Slit
# 27  649308001          AK Beverly denim jeans
# 28  876423002         Perrie Party HW mom dnm
# 29  858225001    Jade Col.block HW Skinny Dnm
# 30  573442001                  Ramone cropped
# 31  416961021            Jade Denim Short TRS
# 32  416961004           Jade Denim Petite Trs
# 33  569176001                 Jade high short
# 34  616390001          Original Straight Deco
# 35  621381019         Jade Denim HW Trash TRS
# 36  621381011            Jade Denim Trash TRS
# 37  621381002      Jade Denim Fancy Trash TRS
# 38  621381001  Jade Trash HW Skinny Denim TRS
# 39  539723014                       Jade high
# 40  539723001                  Jade Denim TRS
# 41  882165001            Monica cord trousers
# 42  740463001         DIV Linn HW side stripe
# 43  610671001                    Perrie trash
# 44  737358001                Molly Knee trash
# 45  572998003               Beverly Denim TRS
# 46  572998001    Beverly HW Loose Mom Fit Dnm
# 47  838325001                  JACKET CROPPED
# 48  639545002    &DENIM Skinny HW ankle Queen
# 49  508933003                     MOLLY FANCY
#
#                                           detail_desc  similarity_score
# 0   Divided Selected Low-rise, ankle-length jeans ...          0.927399
# 1   Divided Selected Low-rise, ankle-length jeans ...          0.927399
# 2   Divided Selected Low-rise, ankle-length jeans ...          0.922989
# 3   Divided Collection 5-pocket, ankle-length jean...          0.922928
# 4   Divided Collection 5-pocket, ankle-length jean...          0.922928
# 5   Divided Collection 5-pocket, ankle-length jean...          0.922546
# 6   Divided Collection 5-pocket, ankle-length jean...          0.922546
# 7   Divided Collection 5-pocket, ankle-length jean...          0.922546
# 8   Divided Collection 5-pocket, high-waisted, ank...          0.922455
# 9   Kids Girl Cropped leggings in washed, superstr...          0.922180
# 10  Womens Trend High-waisted, ankle-length denim ...          0.922134
# 11  Divided Projects High-waisted jeans in washed,...          0.922134
# 12  Ladies Denim Ankle-length jeans in washed, str...          0.922104
# 13  Divided Collection High-waisted jeans in washe...          0.921906
# 14  Divided Selected 5-pocket, ankle-length jeans ...          0.921906
# 15  Womens Trend Ankle-length, 5-pocket jeans in w...          0.921753
# 16  Divided Collection High-waisted jeans in washe...          0.921509
# 17  Divided Selected 5-pocket, high-waisted, ankle...          0.921219
# 18  Divided Selected 5-pocket, high-waisted, ankle...          0.921219
# 19  Divided Selected 5-pocket, high-waisted, ankle...          0.921219
# 20  Divided Collection Ankle-length treggings in s...          0.921127
# 21  Divided Collection Ankle-length treggings in s...          0.921127
# 22  Womens Trend 5-pocket ankle-length jeans in st...          0.921127
# 23  Womens Casual High-waisted, 5-pocket trousers ...          0.921082
# 24  Womens Casual 5-pocket ankle-length jeans in w...          0.921005
# 25  Divided Asia keys Ankle-length jeans in washed...          0.920898
# 26  Divided Collection High-waisted jeans in washe...          0.920792
# 27  Divided Asia keys 5-pocket, ankle-length jeans...          0.920715
# 28  Divided Collection 5-pocket, ankle-length jean...          0.920654
# 29  Divided Collection High-waisted, block-coloure...          0.920578
# 30  Contemporary Casual 5-pocket ankle-length jean...          0.920578
# 31  Divided Collection High-waisted jeans in washe...          0.920456
# 32  Divided Collection High-waisted jeans in washe...          0.920456
# 33  Divided Collection High-waisted jeans in washe...          0.920456
# 34  Divided Collection 5-pocket ankle-length jeans...          0.920441
# 35  Divided Collection High-waisted jeans in washe...          0.920410
# 36  Divided Collection High-waisted jeans in washe...          0.920410
# 37  Divided Collection High-waisted jeans in washe...          0.920410
# 38  Divided Collection High-waisted jeans in washe...          0.920410
# 39  Divided Collection High-waisted jeans in washe...          0.920334
# 40  Divided Collection High-waisted jeans in washe...          0.920334
# 41  Divided Collection 5-pocket, ankle-length trou...          0.920227
# 42  Divided Projects Ankle-length trousers in stre...          0.920212
# 43  Divided Collection 5-pocket, ankle-length jean...          0.920151
# 44  Divided Collection Ankle-length jeggings in st...          0.920135
# 45  Divided Collection 5-pocket, ankle-length jean...          0.920044
# 46  Divided Collection 5-pocket, ankle-length jean...          0.920044
# 47  Young Girl Cropped jacket in washed, slightly ...          0.920013
# 48  H&M+ Ankle-length jeans in washed stretch deni...          0.919952
# 49  Girls Underwear & Basics Hooded jacket with a ...          0.919937

# %%
answer.groupby('detail_desc').count()
# Out:
#                                                     article_id  title  \
# detail_desc
# Contemporary Casual 5-pocket ankle-length jeans...           1      1
# Divided Asia keys 5-pocket, ankle-length jeans ...           1      1
# Divided Asia keys Ankle-length jeans in washed ...           1      1
# Divided Collection 5-pocket ankle-length jeans ...           1      1
# Divided Collection 5-pocket, ankle-length jeans...           1      1
# Divided Collection 5-pocket, ankle-length jeans...           1      1
# Divided Collection 5-pocket, ankle-length jeans...           1      1
# Divided Collection 5-pocket, ankle-length jeans...           2      2
# Divided Collection 5-pocket, ankle-length jeans...           3      3
# Divided Collection 5-pocket, ankle-length jeans...           1      1
# Divided Collection 5-pocket, ankle-length trous...           1      1
# Divided Collection 5-pocket, high-waisted, ankl...           1      1
# Divided Collection Ankle-length jeggings in str...           1      1
# Divided Collection Ankle-length treggings in st...           2      2
# Divided Collection High-waisted jeans in washed...           1      1
# Divided Collection High-waisted jeans in washed...           1      1
# Divided Collection High-waisted jeans in washed...           5      5
# Divided Collection High-waisted jeans in washed...           4      4
# Divided Collection High-waisted jeans in washed...           1      1
# Divided Collection High-waisted, block-coloured...           1      1
# Divided Projects Ankle-length trousers in stret...           1      1
# Divided Projects High-waisted jeans in washed, ...           1      1
# Divided Selected 5-pocket, ankle-length jeans i...           1      1
# Divided Selected 5-pocket, high-waisted, ankle-...           3      3
# Divided Selected Low-rise, ankle-length jeans i...           2      2
# Divided Selected Low-rise, ankle-length jeans i...           1      1
# Girls Underwear & Basics Hooded jacket with a z...           1      1
# H&M+ Ankle-length jeans in washed stretch denim...           1      1
# Kids Girl Cropped leggings in washed, superstre...           1      1
# Ladies Denim Ankle-length jeans in washed, stre...           1      1
# Womens Casual 5-pocket ankle-length jeans in wa...           1      1
# Womens Casual High-waisted, 5-pocket trousers i...           1      1
# Womens Trend 5-pocket ankle-length jeans in stu...           1      1
# Womens Trend Ankle-length, 5-pocket jeans in wa...           1      1
# Womens Trend High-waisted, ankle-length denim j...           1      1
# Young Girl Cropped jacket in washed, slightly s...           1      1
#
#                                                     similarity_score
# detail_desc
# Contemporary Casual 5-pocket ankle-length jeans...                 1
# Divided Asia keys 5-pocket, ankle-length jeans ...                 1
# Divided Asia keys Ankle-length jeans in washed ...                 1
# Divided Collection 5-pocket ankle-length jeans ...                 1
# Divided Collection 5-pocket, ankle-length jeans...                 1
# Divided Collection 5-pocket, ankle-length jeans...                 1
# Divided Collection 5-pocket, ankle-length jeans...                 1
# Divided Collection 5-pocket, ankle-length jeans...                 2
# Divided Collection 5-pocket, ankle-length jeans...                 3
# Divided Collection 5-pocket, ankle-length jeans...                 1
# Divided Collection 5-pocket, ankle-length trous...                 1
# Divided Collection 5-pocket, high-waisted, ankl...                 1
# Divided Collection Ankle-length jeggings in str...                 1
# Divided Collection Ankle-length treggings in st...                 2
# Divided Collection High-waisted jeans in washed...                 1
# Divided Collection High-waisted jeans in washed...                 1
# Divided Collection High-waisted jeans in washed...                 5
# Divided Collection High-waisted jeans in washed...                 4
# Divided Collection High-waisted jeans in washed...                 1
# Divided Collection High-waisted, block-coloured...                 1
# Divided Projects Ankle-length trousers in stret...                 1
# Divided Projects High-waisted jeans in washed, ...                 1
# Divided Selected 5-pocket, ankle-length jeans i...                 1
# Divided Selected 5-pocket, high-waisted, ankle-...                 3
# Divided Selected Low-rise, ankle-length jeans i...                 2
# Divided Selected Low-rise, ankle-length jeans i...                 1
# Girls Underwear & Basics Hooded jacket with a z...                 1
# H&M+ Ankle-length jeans in washed stretch denim...                 1
# Kids Girl Cropped leggings in washed, superstre...                 1
# Ladies Denim Ankle-length jeans in washed, stre...                 1
# Womens Casual 5-pocket ankle-length jeans in wa...                 1
# Womens Casual High-waisted, 5-pocket trousers i...                 1
# Womens Trend 5-pocket ankle-length jeans in stu...                 1
# Womens Trend Ankle-length, 5-pocket jeans in wa...                 1
# Womens Trend High-waisted, ankle-length denim j...                 1
# Young Girl Cropped jacket in washed, slightly s...                 1
